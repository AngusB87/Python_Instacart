# %% [markdown]
# # Exercise 4.8

# %% [markdown]
# ## 1.
# ### Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe

# %% [markdown]
# ## Importing Libraries

# %%
# Importing libraries

import os
import numpy as np
import pandas as pd

# %% [markdown]
# ## Importing Data

# %%
# Set path

path = r"C:\Users\abiha\OneDrive\Documents\IC Project Folder"

# %%
# Importing dataset

ords_prods_merge = pd.read_pickle(r"C:\Users\abiha\OneDrive\Documents\IC Project Folder\2. Data\Prepared Data\order_products_merged_newest.pkl")

# %% [markdown]
# ## 2.
# ### In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
# Finding the average of the order_number column, grouped by department

ords_prods_merge.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ## 3.
# ### Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# #### Compared with the results of the subset, the mean values vary quite significantly across almost every department.
# #### Also, the subset does not return any results for the highest performing departments, 10(bulk) 18(babies). nb department id 21 (missing) not included as I am assuming that could be multiple departments that have not been entered into dataframe
# #### The subset would also suggest that the difference between average orders of departments is higher. Showing some averages as low as 11.2 when the reality is that most fall somewhere between 15.2 and 17.8

# %% [markdown]
# ## 4.

# %% [markdown]
# ### Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
# Create 'max_order' column

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Create flag to show loyal customers

ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
# Create flag to show reglular customers

ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
# Create flag to show new customers

ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Count frequency of each 'loyalty flag'

ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# ## 5.
# ### The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
# Check basic stats of product prices, grouped by loyalty category

ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean','min','max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# ## 6.
# ### The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# #### If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# #### If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# Create average order column in df

ords_prods_merge['average_order'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Check column visible

ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %%
# Create flag for low spenders

ords_prods_merge.loc[ords_prods_merge['average_order'] < 10, 'spender_flag'] = 'Low spender'

# %%
# Create flag for high spenders

ords_prods_merge.loc[ords_prods_merge['average_order'] >= 10, 'spender_flag'] = 'High spender'

# %%
# Frequency count for spender category

ords_prods_merge['spender_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spender_flag, dtype: int64

# %% [markdown]
# ## 7.
#
# ### In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# #### If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# #### If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# #### If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# Create column to show median of days_since_prior_order per user

ords_prods_merge['median_order_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Checking new column

ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %%
# Create flag for non-frequent customers

ords_prods_merge.loc[ords_prods_merge['median_order_frequency'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
# Create flag for regular customers

ords_prods_merge.loc[(ords_prods_merge['median_order_frequency'] > 10) & (ords_prods_merge['median_order_frequency'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
# Create flag for frequent customers

ords_prods_merge.loc[ords_prods_merge['median_order_frequency'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# Check frequency count for customer frequency categories

ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: order_frequency_flag, dtype: int64

# %% [markdown]
# ### Exporting dataframe as pickle file in 'Prepared Data' folder

# %%
ords_prods_merge.to_pickle(os.path.join(path, '2. Data', 'Prepared Data', 'Orders_products_merged_4_8.pkl'))
