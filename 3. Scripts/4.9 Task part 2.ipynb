# %% [markdown]
# ## 1.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
# %matplotlib inline

# %% [markdown]
# ## Import Data

# %%
df = pd.read_pickle(os.path.join(r'/content/drive/MyDrive/AB Instacart Project Folder/2. Data/df_merged_4_9.pkl'))

# %%
# Creating data subset

df_subset = df[:2000000]

# %% [markdown]
# ## 2.

# %%
# Sampling data and applying random number to df

np.random.seed(4)
dev = np.random.rand(len(df)) <= 0.7

# %%
# Creating 2 samples from df

big = df[dev]
small = df[~dev]

# %% [markdown]
# ##### Checking size of 2 sample groups matches full df

# %%
len(df)
# Out:
# 32404859

# %%
len(big) + len(small)
# Out:
# 32404859

# %%
# Creating smaller df consisting of columns required for following line chart

df_2 = small[['orders_day_of_week','prices']]

# %%
line = sns.lineplot(data = df_2, x = 'orders_day_of_week',y = 'prices')

# %%
# Creating new database only using necessary categories

df_3 = df[['orders_day_of_week','prices']]

# %%
# Create line chart

line_2 = sns.lineplot(data = df_3, x = 'orders_day_of_week', y = 'prices')

# %%
# Exporting line chart

line_2.figure.savefig(os.path.join(r'/content/drive/MyDrive/AB Instacart Project Folder/4. Analysis/Visualizations/line_chart.png'))

# %% [markdown]
# ## 3.

# %%
# Creating histogram for order times

order_time_hist = df['order_time_of_day'].plot.hist(bins = 24)

# %% [markdown]
# #### The above histogram illustrates that the most popular times of the day for orders are between 10am and 3pm

# %% [markdown]
# ## 4.

# %%
# Creating a bar chart for "loyalty_flag" column

bar = df['loyalty_flag'].value_counts().sort_index().plot.bar()

# %% [markdown]
# ## 5.

# %%
# Creating a line chart to show prices at different times of day

line_3 = sns.lineplot(data = df, x = 'order_time_of_day', y = 'prices')

# %% [markdown]
# ## 6.

# %%
line_4 = sns.lineplot(data = big, x = 'age', y = 'number_of_dependants')
plt.xlim(18, 81)
plt.ylim(1, 2)
# Out:
# (1.0, 2.0)

# %% [markdown]
# #### There does not appear to be any correlation between age and number of dependants

# %% [markdown]
# ## 7.

# %%
scatter = sns.scatterplot(x = 'age', y = 'income', data = df)

# %% [markdown]
# #### The above scatterplot shows that nobody under the age of 40 is reported to earn more than 40,000. So average income increases with age.

# %% [markdown]
# ## 8.

# %%
# Exporting visualizations

order_time_hist.figure.savefig(os.path.join(r'/content/drive/MyDrive/AB Instacart Project Folder/4. Analysis/Visualizations/order_time_hist.png'))

# %%
bar.figure.savefig(os.path.join(r'/content/drive/MyDrive/AB Instacart Project Folder/4. Analysis/Visualizations/loyalty_bar_chart.png'))

# %%
line_3.figure.savefig(os.path.join(r'/content/drive/MyDrive/AB Instacart Project Folder/4. Analysis/Visualizations/price_order_time_line.png'))

# %%
line_4.figure.savefig(os.path.join(r'/content/drive/MyDrive/AB Instacart Project Folder/4. Analysis/Visualizations/age_dependants_line.png'))

# %%
scatter.figure.savefig(os.path.join(r'/content/drive/MyDrive/AB Instacart Project Folder/4. Analysis/Visualizations/age_income_scatter.png'))
