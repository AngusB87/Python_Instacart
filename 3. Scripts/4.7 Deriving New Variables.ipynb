# %% [markdown]
# # Import Libraries

# %%
# importing libraries

import os
import numpy as np
import pandas as pd

# %% [markdown]
# # Import Data

# %%
# Import ords_prods_merged from pkl file

ords_prods_merged = pd.read_pickle(r"C:\Users\abiha\OneDrive\Documents\IC Project Folder\2. Data\Prepared Data\order_products_merged.pkl")

# %%
# Create smaller df showing first 1,000,000 rows of ords_prods_merged

df = ords_prods_merged[:1000000]

# %%
# Label prices using if-statement

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Apply price_label function to df

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\abiha\AppData\Local\Temp\ipykernel_8764\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
# Frequency count of price ranges in df

df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
# Show max price in 'prices' column of df

df['prices'].max()
# Out:
# 14.8

# %%
# Apply price ranges using loc() function

df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\abiha\AppData\Local\Temp\ipykernel_8764\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Frequency count of price ranges in df

df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
# Applying price labels to ords_prods_merged dataframe

ords_prods_merged.loc[ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merged.loc[(ords_prods_merged['prices'] <= 15) & (ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merged.loc[ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Frequency count of price ranges in ords_prods_merged

ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %%
# Finding busiest day of week using frequency

ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
# Creating for-loop for busiest days of week

result = []

for value in ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Combining for-loop with ords_prods_merged

ords_prods_merged['busiest_day'] = result

# %%
# Frequency count of busiest days

ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# # Task 4.7 Deriving New Variables

# %% [markdown]
# ### Question 2)
# #### Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
# Create new for-loop for new conditions

results = []

for value in ords_prods_merged['orders_day_of_week']:
    if value == 0 or value == 1:
        results.append('Busiest days')
    elif value == 4 or value == 3:
        results.append('Least busy days')
    else:
        results.append('Regularly busy')

# %%
# Create new column and combine with for-loop results

ords_prods_merged['Busiest_days'] = results

# %%
# Check frequencies for new column

ords_prods_merged['Busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy     12916111
# Busiest days       11864412
# Least busy days     7624336
# Name: Busiest_days, dtype: int64

# %% [markdown]
# ### Question 3)
# ### Check the values of this new column for accuracy. Note any observations in markdown format.

# %% [markdown]
# #### The frequencies above match the counts shown in busiest day of week frequencies from step [18]
# #### There are still more orders for the 3 'regularly busy' days when combined compared to the 2 'busiest days'
# #### significant difference for 'least busy days'

# %%
# Checking orders df

ords_prods_merged
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2398795        1             2                   3
# 2           473747        1             3                   3
# 3          2254736        1             4                   4
# 4           431534        1             5                   4
# ...            ...      ...           ...                 ...
# 32404854   1320836   202557            17                   2
# 32404855     31526   202557            18                   5
# 32404856    758936   203436             1                   2
# 32404857   2745165   203436             2                   3
# 32404858   3093936   205420             1                   4
#
#           order_time_of_day  days_since_prior_order  first_order  product_id  \
# 0                         8                     NaN            1         196
# ...

# %% [markdown]
# ### Question 4)
# #### When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
# finding busiest hours of the day

ords_prods_merged['order_time_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_time_of_day, dtype: int64

# %%
# Creating a for-loop to break down times into 3 groups, “Most orders,” “Average orders,” and “Fewest orders.”

findings = []

for value in ords_prods_merged['order_time_of_day']:
    if value in [10,11,14,15,13,12,16,9]:
        findings.append('Most orders')
    elif value in [17,8,18,19,20,7,21,22]:
        findings.append('Average orders')
    else:
        findings.append('Fewest orders')

# %%
# Combining findings for-loop with ords_prods_merged df

ords_prods_merged['busiest_period_of_day'] = findings

# %% [markdown]
# ### Question 5)
# #### Print the frequency for this new column.

# %%
# Showing frequency for new column 'busiest_period_of_day'

ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: busiest_period_of_day, dtype: int64

# %%
# Exporting updated df as pickle file

ords_prods_merged.to_pickle(os.path.join(r"C:\Users\abiha\OneDrive\Documents\IC Project Folder\2. Data\Prepared Data", 'order_products_merged_newest.pkl'))
